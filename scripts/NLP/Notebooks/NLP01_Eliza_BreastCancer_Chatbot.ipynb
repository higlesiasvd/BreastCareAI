# %%
import re
import random

# %%
class MammaELIZA:
    def __init__(self):
        # Mensaje de descargo de responsabilidad médica
        self.disclaimer = ("Nota: Soy un programa informático de apoyo. No soy médico ni puedo "
                          "proporcionar diagnósticos o consejos médicos personalizados. Por favor, "
                          "consulta siempre con profesionales de la salud para decisiones médicas.")
        
        # Definir patrones y respuestas específicas para cáncer de mama
        self.patterns = [
            # Saludos y despedidas
            (r'.*\b(hola|saludos|hey|buenos días|buenas tardes|buenas noches)\b.*', [
                "Hola. ¿En qué puedo ayudarte hoy con respecto al cáncer de mama?",
                "Hola. Estoy aquí para brindarte información y apoyo sobre el cáncer de mama. ¿Cómo puedo ayudarte?",
                "Hola. Soy un asistente virtual sobre cáncer de mama. ¿Qué te gustaría saber?"
            ]),
            (r'.*\b(adiós|chao|hasta luego|nos vemos)\b.*', [
                "Adiós. Si necesitas más información sobre cáncer de mama en el futuro, no dudes en volver.",
                "Hasta pronto. Recuerda la importancia de las revisiones regulares y el autoexamen.",
                "Cuídate mucho. Recuerda que el apoyo emocional es importante durante todo el proceso."
            ]),
            
            # Detección y diagnóstico
            (r'.*\b(síntoma|síntomas)\b.*', [
                "Los síntomas comunes del cáncer de mama incluyen bultos, cambios en la forma o textura del pecho, secreción del pezón o cambios en la piel. ¿Has notado alguno de estos síntomas?",
                "Es importante saber que muchos síntomas de cáncer de mama también pueden ser causados por otras condiciones benignas. ¿Te preocupa algún síntoma específico?",
                "Los síntomas pueden variar, pero cualquier cambio inusual debería ser consultado con un médico. ¿Hay algún cambio que te preocupe?"
            ]),
            (r'.*\b(autoexamen|autoexploración)\b.*', [
                "El autoexamen mensual es recomendable. Se realiza una semana después de la menstruación, observando frente al espejo y palpando en posición acostada y de pie. ¿Conoces la técnica correcta?",
                "Para el autoexamen, es importante conocer cómo se sienten normalmente tus senos para detectar cambios. ¿Realizas autoexámenes regularmente?",
                "El autoexamen no sustituye a las mamografías pero es un complemento importante. Se recomienda realizarlo una vez al mes. ¿Te gustaría más información sobre cómo hacerlo?"
            ]),
            (r'.*\b(mamografía|mamografías)\b.*', [
                "Las mamografías son una herramienta crucial para la detección temprana. Se recomienda realizarlas anualmente a partir de los 40-50 años, según las guías médicas. ¿Has tenido alguna mamografía recientemente?",
                "La mamografía puede detectar tumores antes de que sean palpables. Es un procedimiento rápido aunque puede ser algo incómodo. ¿Tienes preguntas específicas sobre las mamografías?",
                "Existen diferentes guías sobre cuándo comenzar con las mamografías regulares. Tu médico puede recomendarte un calendario apropiado según tus factores de riesgo. ¿Conoces tus factores de riesgo?"
            ]),
            (r'.*\b(detect|encontr|hallazgo)\b.*\b(bulto|masa|nódulo)\b.*', [
                "Encontrar un bulto puede ser alarmante, pero es importante recordar que la mayoría son benignos. Lo más recomendable es consultar con un médico para una evaluación adecuada. ¿Ya has consultado con un especialista?",
                "Ante el hallazgo de un bulto, tu médico probablemente realizará un examen físico y puede solicitar pruebas de imagen como una mamografía o ecografía. ¿Has tenido ya alguna de estas pruebas?",
                "La evaluación de un bulto puede incluir varios pasos, incluyendo biopsia si es necesario. Intenta mantener la calma mientras sigues el proceso diagnóstico. ¿Cómo te estás sintiendo al respecto?"
            ]),
            (r'.*\b(biopsia)\b.*', [
                "La biopsia es el método definitivo para determinar si un tejido es canceroso. Consiste en extraer una pequeña muestra del tejido sospechoso para analizarla. ¿Te han recomendado una biopsia?",
                "Existen diferentes tipos de biopsias: con aguja fina, con aguja gruesa o quirúrgicas. El tipo dependerá de varios factores que tu médico evaluará. ¿Sabes qué tipo te han recomendado?",
                "Esperar los resultados de una biopsia puede ser estresante. Es normal sentir ansiedad durante este periodo. ¿Cómo estás manejando la espera?"
            ]),
            
            # Tratamientos
            (r'.*\b(tratamiento|tratamientos)\b.*', [
                "Los tratamientos para el cáncer de mama pueden incluir cirugía, radioterapia, quimioterapia, terapia hormonal e inmunoterapia, dependiendo del tipo y etapa. ¿Hay algún tratamiento específico sobre el que quieras saber más?",
                "El plan de tratamiento se personaliza según el tipo de cáncer, etapa, características genéticas y preferencias personales. ¿Estás considerando opciones de tratamiento actualmente?",
                "Es importante discutir con tu equipo médico los beneficios y efectos secundarios de cada tratamiento. ¿Has tenido oportunidad de hablar sobre esto con tu médico?"
            ]),
            (r'.*\b(cirugía|lumpectomía|mastectomía)\b.*', [
                "Existen diferentes tipos de cirugía, desde la lumpectomía (conservación del seno) hasta la mastectomía (extirpación completa). La elección depende de varios factores. ¿Te han hablado sobre opciones quirúrgicas?",
                "La reconstrucción mamaria es una opción después de la mastectomía, y puede realizarse durante la misma cirugía o posteriormente. ¿Has considerado esta opción?",
                "La recuperación después de la cirugía varía según el procedimiento, pero generalmente incluye un periodo de descanso y rehabilitación. ¿Tienes preocupaciones sobre el proceso de recuperación?"
            ]),
            (r'.*\b(quimioterapia|quimio)\b.*', [
                "La quimioterapia usa medicamentos para destruir células cancerosas. Puede administrarse antes de la cirugía (neoadyuvante) o después (adyuvante). ¿Tienes dudas específicas sobre la quimioterapia?",
                "Los efectos secundarios de la quimioterapia pueden incluir fatiga, náuseas, pérdida de cabello y otros, pero existen medicamentos y estrategias para manejarlos. ¿Te preocupan los efectos secundarios?",
                "No todas las pacientes con cáncer de mama necesitan quimioterapia. La decisión se basa en el tipo de cáncer, etapa y otros factores. ¿Has discutido con tu médico si la quimioterapia es adecuada para tu caso?"
            ]),
            (r'.*\b(radioterapia|radiación)\b.*', [
                "La radioterapia utiliza radiación de alta energía para destruir células cancerosas. Suele aplicarse después de la cirugía conservadora para reducir el riesgo de recurrencia. ¿Te han recomendado radioterapia?",
                "Un curso típico de radioterapia puede durar varias semanas con sesiones diarias cortas. Los efectos secundarios pueden incluir fatiga y cambios en la piel del área tratada. ¿Te preocupan estos efectos?",
                "Las técnicas modernas de radioterapia son muy precisas, minimizando el daño a los tejidos sanos. ¿Tienes preguntas sobre el procedimiento de radioterapia?"
            ]),
            (r'.*\b(hormon|terapia hormonal)\b.*', [
                "La terapia hormonal se usa para cánceres sensibles a hormonas (ER+/PR+). Medicamentos como tamoxifeno o inhibidores de aromatasa pueden reducir el riesgo de recurrencia. ¿Te han hablado sobre la terapia hormonal?",
                "La terapia hormonal puede continuar durante varios años después de otros tratamientos. Tiene efectos secundarios diferentes a la quimioterapia. ¿Conoces los posibles efectos secundarios?",
                "No todos los cánceres de mama responden a la terapia hormonal. Depende de si las células cancerosas tienen receptores hormonales. ¿Sabes si tu diagnóstico incluye esta información?"
            ]),
            
            # Apoyo emocional
            (r'.*\b(miedo|asustada|temor|preocupada|ansiedad)\b.*', [
                "Es completamente normal sentir miedo ante un diagnóstico de cáncer de mama o la posibilidad de tenerlo. ¿Hay algo específico que te preocupe más?",
                "La ansiedad durante este proceso es una respuesta natural. Hablar con profesionales, grupos de apoyo o seres queridos puede ayudar. ¿Tienes personas con quien compartir tus preocupaciones?",
                "El miedo a lo desconocido es uno de los aspectos más difíciles. Obtener información clara puede ayudar a reducir la ansiedad. ¿Hay alguna información específica que podría ayudarte a sentirte más en control?"
            ]),
            (r'.*\b(deprimida|depresión|triste|desesperada)\b.*', [
                "Los sentimientos de tristeza son comunes durante este proceso. Si sientes que la depresión afecta tu vida diaria, es importante buscar apoyo profesional. ¿Has considerado hablar con un psicólogo?",
                "Cuidar tu bienestar emocional es tan importante como el tratamiento físico. Existen recursos específicos para el apoyo emocional durante el cáncer. ¿Te gustaría conocer algunos?",
                "La montaña rusa emocional del cáncer puede ser intensa. Recuerda que no hay emociones 'correctas' o 'incorrectas' en este proceso. ¿Cómo estás manejando estos sentimientos actualmente?"
            ]),
            (r'.*\b(apoyo|ayuda|soporte)\b.*', [
                "Existen diversos grupos de apoyo para personas con cáncer de mama, tanto presenciales como online. Conectar con otros que han pasado por experiencias similares puede ser reconfortante. ¿Has considerado unirte a un grupo de apoyo?",
                "Además de familiares y amigos, hay profesionales como trabajadores sociales oncológicos que pueden proporcionar apoyo práctico y emocional. ¿Has contactado con algún servicio de apoyo?",
                "Organizaciones como la Asociación Española Contra el Cáncer ofrecen recursos gratuitos de apoyo. ¿Te gustaría información sobre recursos específicos en tu área?"
            ]),
            
            # Prevención y factores de riesgo
            (r'.*\b(prevenir|prevención)\b.*', [
                "Aunque no existe prevención garantizada, mantener un peso saludable, limitar el alcohol, hacer ejercicio regularmente y evitar la terapia hormonal a largo plazo puede reducir el riesgo. ¿Tienes preguntas sobre estos factores?",
                "La detección temprana mediante autoexámenes y mamografías regulares es clave para un mejor pronóstico. ¿Sigues alguna rutina de detección?",
                "Conocer tu historial familiar es importante para evaluar tu riesgo. Si tienes antecedentes familiares, tu médico puede recomendar pruebas más frecuentes o tempranas. ¿Conoces tu historial familiar respecto al cáncer de mama?"
            ]),
            (r'.*\b(riesgo|factores|predisposición)\b.*', [
                "Los factores de riesgo incluyen ser mujer, edad avanzada, antecedentes familiares, ciertas mutaciones genéticas (BRCA1/2), inicio temprano de la menstruación, menopausia tardía y terapia hormonal. ¿Te preocupa algún factor específico?",
                "Es importante recordar que tener factores de riesgo no significa que desarrollarás cáncer, y muchas personas sin factores de riesgo también pueden desarrollarlo. ¿Hay algún factor específico que te preocupe?",
                "Si tienes alto riesgo, existen opciones preventivas como medicamentos o cirugía preventiva. Estas decisiones son muy personales y deben discutirse con especialistas. ¿Has hablado con tu médico sobre tu nivel de riesgo?"
            ]),
            (r'.*\b(genética|hereditario|BRCA|familiar)\b.*', [
                "Aproximadamente 5-10% de los cánceres de mama son hereditarios. Las mutaciones más conocidas son BRCA1 y BRCA2, pero hay otras. ¿Tienes antecedentes familiares de cáncer de mama u ovario?",
                "Las pruebas genéticas pueden identificar mutaciones que aumentan el riesgo. Son recomendables en casos de fuerte historia familiar. ¿Has considerado hacerte pruebas genéticas?",
                "Si se identifica una mutación genética, existen opciones como vigilancia intensiva, medicamentos preventivos o cirugía profiláctica. ¿Has discutido estas opciones con un especialista en genética?"
            ]),
            
            # Supervivencia y recuperación
            (r'.*\b(pronóstico|sobrevivir|supervivencia)\b.*', [
                "El pronóstico del cáncer de mama ha mejorado significativamente. Los factores que lo afectan incluyen el tipo de cáncer, etapa, grado, edad y salud general. ¿Te han dado información sobre tu pronóstico específico?",
                "Las tasas de supervivencia a 5 años para cáncer de mama localizado superan el 90%. Es importante recordar que las estadísticas son generales y cada caso es único. ¿Has hablado con tu médico sobre expectativas en tu caso?",
                "Muchas personas viven vidas plenas después del tratamiento. Los avances en detección temprana y tratamientos han mejorado significativamente las tasas de supervivencia. ¿Tienes preocupaciones específicas sobre el futuro?"
            ]),
            (r'.*\b(recaída|recurrencia|vuelva)\b.*', [
                "El temor a la recurrencia es común entre supervivientes. Seguir el plan de seguimiento médico y mantener un estilo de vida saludable son importantes. ¿Tienes un plan de seguimiento establecido?",
                "No todas las personas experimentan recurrencia. Los tratamientos actuales están diseñados para reducir este riesgo. ¿Hay alguna estrategia específica que te interese para reducir el riesgo?",
                "Aprender a manejar la ansiedad sobre la recurrencia es parte importante de la supervivencia. Técnicas de mindfulness y terapia pueden ser útiles. ¿Has considerado estos enfoques?"
            ]),
            (r'.*\b(reconstrucción|implantes|prótesis)\b.*', [
                "La reconstrucción mamaria puede realizarse durante la mastectomía o posteriormente. Existen diferentes técnicas, incluyendo implantes o uso de tejido propio. ¿Has discutido estas opciones con un cirujano plástico?",
                "La decisión sobre la reconstrucción es muy personal. Algunas mujeres optan por ella, otras prefieren prótesis externas, y otras eligen no hacer ninguna de las dos. ¿Qué opción te parece más adecuada para ti?",
                "La cobertura de seguros para reconstrucción mamaria está garantizada por ley en muchos países. ¿Has investigado la cobertura de tu seguro para estos procedimientos?"
            ]),
            (r'.*\b(trabajo|laboral|empleo)\b.*', [
                "Manejar el trabajo durante el tratamiento puede ser complicado. Conocer tus derechos laborales y opciones de adaptación es importante. ¿Has hablado con recursos humanos sobre tu situación?",
                "Algunas personas continúan trabajando durante el tratamiento, mientras otras necesitan tomarse un tiempo. Depende del tipo de trabajo y tratamiento. ¿Qué te recomendó tu equipo médico?",
                "Existen protecciones legales para trabajadores con cáncer. Un trabajador social oncológico puede ayudarte a navegar estos aspectos. ¿Has consultado con uno?"
            ]),
            
            # Preguntas específicas
            (r'.*\b(dolor|duele)\b.*\b(pecho|seno|mama)\b.*', [
                "El dolor mamario rara vez es un síntoma de cáncer de mama, pero cualquier síntoma persistente debe ser evaluado por un médico. ¿El dolor es en un área específica o general?",
                "Existen muchas causas benignas de dolor mamario, incluyendo cambios hormonales, quistes o mastitis. ¿Has notado algún otro síntoma además del dolor?",
                "Si el dolor te preocupa, es importante consultar con un médico para una evaluación adecuada. ¿Has programado una cita médica para evaluar este síntoma?"
            ]),
            (r'.*\b(metástasis|extendido|propagado)\b.*', [
                "El cáncer de mama metastásico es aquel que se ha propagado a otras partes del cuerpo. Aunque es más desafiante de tratar, existen múltiples opciones terapéuticas. ¿Te han dado información sobre tratamientos específicos?",
                "Vivir con cáncer metastásico puede implicar diferentes enfoques de tratamiento centrados tanto en prolongar la vida como en mantener su calidad. ¿Qué aspectos te preocupan más?",
                "Los avances en tratamientos para cáncer metastásico continúan mejorando las expectativas. Muchas personas viven años con buena calidad de vida. ¿Has conectado con grupos de apoyo específicos para esta situación?"
            ]),
            (r'.*\beffectos secundarios\b.*', [
                "Los efectos secundarios varían según el tratamiento. Es importante discutirlos con tu equipo médico para estar preparada y conocer estrategias de manejo. ¿Hay algún efecto secundario específico que te preocupe?",
                "Existen medicamentos y técnicas que pueden ayudar a manejar muchos efectos secundarios comunes. No dudes en comunicar cualquier malestar a tu equipo médico. ¿Estás experimentando efectos secundarios actualmente?",
                "Recordar que muchos efectos secundarios son temporales puede ayudar a sobrellevarlos. Mantener un diario de síntomas puede ser útil para discutirlos con tu médico. ¿Has considerado llevar un registro de tus síntomas?"
            ]),
            
            # Patrones generales
            (r'.*\b(médico|doctor|oncólogo)\b.*', [
                "Es fundamental tener una buena comunicación con tu equipo médico. Preparar preguntas antes de las citas puede ser útil. ¿Te sientes cómoda hablando con tu médico?",
                "Si tienes dudas sobre las recomendaciones de tu médico, obtener una segunda opinión es una práctica común y respetada. ¿Has considerado esta opción?",
                "Un equipo multidisciplinario (oncólogos, cirujanos, radiólogos, etc.) suele estar involucrado en el tratamiento del cáncer de mama. ¿Sientes que comprendes el rol de cada especialista en tu equipo?"
            ]),
            (r'.*\b(información|recursos|dónde puedo)\b.*', [
                "Existen muchas fuentes confiables de información sobre cáncer de mama, como la Asociación Española Contra el Cáncer, la American Cancer Society o Breastcancer.org. ¿Has consultado alguna de estas fuentes?",
                "Es importante buscar información en fuentes confiables y actualizadas. Tu equipo médico también puede recomendarte recursos específicos. ¿Qué tipo de información estás buscando?",
                "Las bibliotecas de hospitales oncológicos suelen tener materiales educativos y las asociaciones contra el cáncer ofrecen recursos gratuitos. ¿Te interesa algún tema específico?"
            ]),
            (r'.*\b(por qué a mí|por qué yo)\b.*', [
                "Es natural preguntarse 'por qué yo' después de un diagnóstico. El cáncer de mama puede afectar a cualquier persona, incluso con estilos de vida saludables. ¿Cómo estás procesando tus sentimientos sobre esto?",
                "Buscar un 'porqué' es una respuesta humana, pero muchas veces no hay una respuesta clara. Puede ser más útil centrarse en el 'qué hacer ahora'. ¿Has encontrado formas de avanzar con esta incertidumbre?",
                "Esta pregunta refleja lo difícil que es aceptar algo tan impactante. Hablar con otras personas que han pasado por esto o con un profesional de salud mental puede ayudar. ¿Has considerado buscar este tipo de apoyo?"
            ]),
            (r'.*\b(seguro|cobertura|costo|precio)\b.*', [
                "Los aspectos financieros del tratamiento del cáncer son importantes. Muchos hospitales tienen coordinadores financieros o trabajadores sociales que pueden ayudar a navegar estos temas. ¿Has hablado con alguno de ellos?",
                "Existen programas de asistencia financiera para pacientes con cáncer. Organizaciones sin fines de lucro pueden proporcionar información sobre recursos disponibles. ¿Necesitas ayuda para encontrar estos recursos?",
                "Entender tu cobertura de seguro es importante. Mantener registros detallados de gastos médicos y comunicación con la aseguradora puede ser útil. ¿Has revisado los detalles de tu cobertura?"
            ]),
            
            # Respuestas de referencia a profesionales
            (r'.*\b(necesito ayuda|urgente|emergencia)\b.*', [
                "Si estás experimentando una emergencia médica, debes contactar inmediatamente con servicios de emergencia o acudir a urgencias. ¿Estás experimentando síntomas que requieren atención inmediata?",
                "Para situaciones urgentes, lo mejor es contactar directamente con tu equipo médico. Muchos oncólogos tienen líneas de atención para pacientes. ¿Tienes el contacto de tu equipo médico?",
                "La salud mental también puede requerir atención urgente. Si experimentas pensamientos de hacerte daño, contacta con un servicio de crisis inmediatamente. ¿Necesitas información sobre estos servicios?"
            ]),
            (r'.*\b(qué debo hacer|qué hago|cómo procedo)\b.*', [
                "La mejor guía para pasos específicos vendrá de profesionales de la salud que conocen tu situación particular. ¿Has podido consultar con tu médico sobre esto?",
                "Cada situación es única, y las recomendaciones varían según muchos factores individuales. Un profesional de la salud podrá darte orientación personalizada. ¿Puedes concertar una cita pronto?",
                "Para preguntas específicas sobre tu situación, consultar con tu equipo médico te dará la información más precisa. ¿Hay algo que pueda aclararte mientras tanto en términos generales?"
            ]),
            
            # Preguntas generales o de información
            (r'.*\?', [
                "Esa es una pregunta importante sobre el cáncer de mama. ¿Hay algún aspecto específico que te gustaría explorar más a fondo?",
                "Gracias por tu pregunta. El cáncer de mama es un tema complejo con muchos aspectos a considerar. ¿Puedes compartir más sobre lo que te gustaría saber?",
                "Es una buena pregunta. La información sobre el cáncer de mama está en constante evolución con nuevas investigaciones. ¿Hay algo específico que te preocupa sobre este tema?"
            ]),
            # Definición del cáncer de mama
            (r'.*\b(qué|que) (es|son) (el|los)? (cáncer|cancer) de (mama|pecho|seno)\b.*', [
                "El cáncer de mama es una enfermedad en la que las células mamarias crecen de forma descontrolada, formando tumores que pueden invadir el tejido circundante. Comienza generalmente en los conductos que transportan leche al pezón o en las glándulas productoras de leche. ¿Te gustaría saber sobre algún aspecto específico?",
                "El cáncer de mama ocurre cuando el ADN de las células mamarias muta, haciendo que crezcan anormalmente y se multipliquen. Estas células anormales forman tumores que pueden propagarse. Aunque afecta principalmente a mujeres, los hombres también pueden desarrollarlo. ¿Hay algo específico que te interese saber?",
                "El cáncer de mama es una proliferación maligna de células que se originan en el tejido mamario. Es uno de los cánceres más comunes en mujeres a nivel mundial, aunque representa menos del 1% de los cánceres en hombres. ¿Te gustaría información sobre detección temprana o factores de riesgo?"
            ]),

            # Metástasis
            (r'.*\b(qué|que) es (la|el) metástasis\b.*', [
                "La metástasis ocurre cuando las células cancerosas se separan del tumor original y viajan a través del sistema sanguíneo o linfático para formar nuevos tumores en otras partes del cuerpo. En el cáncer de mama, los sitios más comunes de metástasis son huesos, pulmones, hígado y cerebro. ¿Te preocupa algún aspecto específico de la metástasis?",
                "La metástasis representa la propagación del cáncer desde su sitio de origen a otras partes del cuerpo. Esto ocurre cuando las células cancerosas adquieren la capacidad de desprenderse del tumor primario, entrar en los vasos sanguíneos o linfáticos, y establecerse en tejidos distantes. ¿Hay algún aspecto sobre la metástasis que te gustaría conocer mejor?",
                "La metástasis es el proceso por el cual el cáncer se extiende más allá de su ubicación inicial. Cuando el cáncer de mama se vuelve metastásico, significa que se ha propagado a órganos distantes. Aunque es más difícil de tratar en esta etapa, existen múltiples opciones terapéuticas para controlar la enfermedad. ¿Tienes preguntas específicas sobre el tratamiento de la metástasis?"
            ]),

            # Tipos de cáncer de mama
            (r'.*\b(tipos|clases) de (cáncer|cancer) de (mama|pecho|seno)\b.*', [
                "Los principales tipos de cáncer de mama incluyen: carcinoma ductal in situ (CDIS), carcinoma ductal invasivo (CDI), carcinoma lobulillar invasivo (CLI), y tipos menos comunes como inflamatorio, medular, mucinoso, papilar y tubular. Cada tipo tiene características distintas que influyen en el tratamiento. ¿Te interesa algún tipo específico?",
                "El cáncer de mama se clasifica por su origen (ductal o lobulillar), invasividad (in situ o invasivo), y perfil molecular (luminal A/B, HER2-positivo, o triple negativo). Esta clasificación es crucial para determinar el tratamiento más adecuado. ¿Hay alguna clasificación sobre la que quieras más información?",
                "Existen diversos tipos de cáncer de mama que se diferencian por sus características celulares, expresión de receptores hormonales y comportamiento biológico. El tipo más común es el carcinoma ductal invasivo, representando aproximadamente el 70-80% de todos los casos. ¿Deseas información sobre algún tipo específico?"
            ]),

            # Etapas/Estadios
            (r'.*\b(etapas|estadios|fases) del (cáncer|cancer) de (mama|pecho|seno)\b.*', [
                "El cáncer de mama se clasifica en etapas del 0 al IV. La etapa 0 es no invasiva (in situ), las etapas I y II son cáncer invasivo temprano, la etapa III es cáncer localmente avanzado, y la etapa IV indica que el cáncer ha hecho metástasis a otras partes del cuerpo. ¿Hay alguna etapa específica sobre la que quieras más información?",
                "La estadificación del cáncer de mama utiliza el sistema TNM: Tumor (tamaño), Nódulos (afectación de ganglios linfáticos) y Metástasis (propagación a otros órganos). Esto determina la etapa (0-IV) que guía las decisiones de tratamiento. ¿Te gustaría saber cómo se determina la etapa específicamente?",
                "Las etapas del cáncer de mama van del 0 al IV, indicando la extensión de la enfermedad. Esta clasificación considera el tamaño del tumor, la afectación de los ganglios linfáticos y la presencia de metástasis. El pronóstico y tratamiento varían considerablemente según la etapa. ¿Deseas conocer las tasas de supervivencia asociadas con cada etapa?"
            ]),

            # Subtipos moleculares
            (r'.*\b(triple negativo|HER2|hormonal|receptor|luminal|molecular)\b.*', [
                "Los subtipos moleculares del cáncer de mama incluyen: Luminal A (HR+/HER2-), Luminal B (HR+/HER2+ o HR+/HER2- con alto Ki-67), HER2-positivo (HR-/HER2+), y Triple Negativo (HR-/HER2-). Cada subtipo responde diferentemente a los tratamientos. ¿Te gustaría información sobre algún subtipo específico?",
                "El cáncer triple negativo carece de receptores de estrógeno, progesterona y HER2, lo que limita las opciones de tratamiento dirigido, pero la quimioterapia suele ser efectiva. Los tumores HER2-positivos tienden a crecer más rápido pero responden bien a terapias dirigidas anti-HER2. ¿Quieres saber más sobre alguno de estos subtipos?",
                "Los cánceres con receptores hormonales positivos (estrógeno y/o progesterona) suelen responder bien a terapias hormonales. Los cánceres HER2-positivos tienen sobreexpresión de la proteína HER2 y se benefician de terapias dirigidas específicas como trastuzumab. ¿Hay algún aspecto de estos subtipos que te interese particularmente?"
            ]),

            # Ganglios linfáticos
            (r'.*\b(ganglio|ganglios|linfáticos|axilares)\b.*', [
                "Los ganglios linfáticos son parte del sistema linfático que ayuda a combatir infecciones. En el cáncer de mama, los ganglios axilares (en la axila) son importantes porque suelen ser los primeros sitios donde el cáncer se propaga desde la mama. La evaluación de estos ganglios es crucial para la estadificación. ¿Tienes preguntas específicas sobre la evaluación de ganglios?",
                "Durante la cirugía de cáncer de mama, a menudo se examina el ganglio centinela, que es el primer ganglio que recibe drenaje linfático del tumor. Si este ganglio está libre de cáncer, generalmente significa que los demás ganglios también lo están, evitando la necesidad de extraer más ganglios. ¿Te interesa saber sobre el procedimiento del ganglio centinela?",
                "La afectación de los ganglios linfáticos es un factor pronóstico importante en el cáncer de mama. Cuando las células cancerosas se encuentran en los ganglios, indica que el cáncer tiene capacidad de propagarse, lo que puede influir en las decisiones de tratamiento, como la necesidad de quimioterapia. ¿Hay algo específico sobre este tema que te gustaría explorar?"
            ]),

            # Remisión
            (r'.*\b(remisión|remision)\b.*', [
                "La remisión en cáncer de mama significa que no hay evidencia detectable de la enfermedad después del tratamiento. La remisión completa implica la desaparición de todos los signos de cáncer, mientras que la remisión parcial significa una reducción significativa pero no total. ¿Te gustaría saber más sobre las tasas de remisión?",
                "Estar en remisión no es lo mismo que estar curado, ya que algunas células cancerosas pueden permanecer indetectables. Sin embargo, cuanto más tiempo pasa en remisión, mayor es la probabilidad de que el cáncer no regrese. El seguimiento médico regular es crucial durante este período. ¿Tienes preguntas sobre el seguimiento después del tratamiento?",
                "Alcanzar la remisión es el objetivo principal del tratamiento. Después de la remisión, muchas personas siguen recibiendo tratamiento adyuvante para reducir el riesgo de recurrencia. La duración de este tratamiento varía según el tipo de cáncer y factores individuales. ¿Quieres información sobre tratamientos posremisión?"
            ]),

            # Biomarcadores
            (r'.*\b(biomarcador|biomarcadores|marcadores|marcador tumoral)\b.*', [
                "Los biomarcadores en cáncer de mama son características medibles que indican procesos biológicos normales, patogénicos o respuestas a tratamientos. Los más comunes incluyen receptores de estrógeno (ER), progesterona (PR), HER2 y Ki-67. Estos ayudan a determinar el subtipo de cáncer y guiar el tratamiento. ¿Te interesa algún biomarcador específico?",
                "Los marcadores tumorales son sustancias encontradas en sangre, orina o tejidos que pueden indicar la presencia de cáncer. En el cáncer de mama, se utilizan principalmente para monitorear la respuesta al tratamiento o detectar recurrencias, no como método de diagnóstico primario. ¿Hay algún aspecto específico que te gustaría conocer?",
                "Los biomarcadores son cruciales para la medicina personalizada en cáncer de mama. Permiten adaptar los tratamientos según las características específicas del tumor. Por ejemplo, tumores con alta expresión de HER2 responden a terapias anti-HER2, mientras que los tumores con receptores hormonales positivos responden a terapia hormonal. ¿Quieres saber más sobre cómo se analizan estos biomarcadores?"
            ]),

            # Densidad mamaria
            (r'.*\b(densidad|denso|densa) (mamaria|mama|pecho|seno)\b.*', [
                "La densidad mamaria se refiere a la proporción de tejido fibroglandular (denso) versus tejido graso (no denso) en la mama. Las mamas densas tienen más tejido fibroglandular, lo que puede dificultar la detección de cánceres en mamografías ya que tanto el tejido denso como los tumores aparecen blancos. ¿Te preocupa tu densidad mamaria?",
                "Tener mamas densas es común y normal, pero representa un factor de riesgo moderado para desarrollar cáncer de mama y dificulta la interpretación de mamografías. Para mujeres con alta densidad mamaria, pueden recomendarse pruebas complementarias como ultrasonido o resonancia magnética. ¿Te han informado sobre tu densidad mamaria en alguna mamografía?",
                "La densidad mamaria puede clasificarse en cuatro categorías: casi completamente grasa, áreas dispersas de densidad, heterogéneamente densa, y extremadamente densa. Esta clasificación es importante porque las mujeres con mamas densas pueden beneficiarse de métodos de detección adicionales además de la mamografía estándar. ¿Has discutido con tu médico qué opciones de detección son mejores para ti?"
            ]),

            # Mastectomía vs. Lumpectomía
            (r'.*\bdiferen(cia|cias) (entre )?(mastectom[íi]a|mastectomia)( y| versus| vs.?)? (lumpectom[íi]a|lumpectomia)\b.*', [
                "La principal diferencia entre mastectomía y lumpectomía es la cantidad de tejido que se extirpa. En la lumpectomía (cirugía conservadora), solo se extirpa el tumor y un margen de tejido sano circundante, preservando la mayor parte de la mama. En la mastectomía, se extirpa toda la mama. La lumpectomía generalmente va seguida de radioterapia. ¿Te están considerando para alguno de estos procedimientos?",
                "La lumpectomía ofrece la ventaja de conservar la mama, con resultados de supervivencia similares a la mastectomía para muchos cánceres en etapas tempranas. Sin embargo, no todas las pacientes son candidatas para lumpectomía, dependiendo del tamaño y ubicación del tumor, tamaño de la mama, y otros factores. ¿Deseas saber si podrías ser candidata para cirugía conservadora?",
                "Tanto la mastectomía como la lumpectomía son efectivas para tratar el cáncer de mama. La elección depende de varios factores, incluyendo el tamaño y ubicación del tumor, presencia de múltiples tumores, antecedentes de radioterapia, factores genéticos, y preferencias personales. Es una decisión que debe tomarse en conjunto con tu equipo médico. ¿Has discutido estas opciones con tu cirujano?"
            ]),

            # Terapia adyuvante vs. neoadyuvante
            (r'.*\b(adyuvante|neoadyuvante|antes de la cirug[íi]a|despu[ée]s de la cirug[íi]a)\b.*', [
                "La terapia adyuvante se administra después de la cirugía para eliminar cualquier célula cancerosa residual y reducir el riesgo de recurrencia. La terapia neoadyuvante se administra antes de la cirugía para reducir el tamaño del tumor, facilitando la cirugía o permitiendo cirugías menos extensas. Ambas pueden incluir quimioterapia, radioterapia o terapia hormonal. ¿Cuál de estas opciones estás considerando?",
                "La terapia neoadyuvante ofrece la ventaja de poder evaluar la respuesta del tumor al tratamiento en tiempo real. Una respuesta completa (cuando no queda tumor visible en la cirugía) puede ser un indicador de buen pronóstico. Además, puede convertir algunos tumores inoperables en operables. ¿Te han recomendado este enfoque?",
                "La elección entre terapia adyuvante y neoadyuvante depende de varios factores, incluyendo el tamaño y etapa del tumor, subtipo molecular, y objetivos específicos del tratamiento. Tu oncólogo puede recomendarte el enfoque más adecuado basado en las características particulares de tu caso. ¿Has discutido estas opciones con tu equipo médico?"
            ]),

            # Inmunoterapia
            (r'.*\b(inmunoterapia|immunoterapia)\b.*', [
                "La inmunoterapia es un tratamiento que utiliza el propio sistema inmunológico del cuerpo para combatir el cáncer. En cáncer de mama, su papel está en desarrollo, siendo más prometedora en subtipos como el triple negativo. Los inhibidores de puntos de control inmunitario como pembrolizumab han mostrado resultados alentadores en algunos casos. ¿Te gustaría saber si podrías ser candidata para inmunoterapia?",
                "A diferencia de otros cánceres, la inmunoterapia aún no es un tratamiento estándar para la mayoría de los cánceres de mama. Sin embargo, está siendo activamente investigada en ensayos clínicos, especialmente para cánceres metastásicos o avanzados. La respuesta varía según características específicas del tumor. ¿Estás interesada en información sobre ensayos clínicos de inmunoterapia?",
                "La inmunoterapia funciona mejor en tumores con alta carga mutacional o expresión de PD-L1. Los estudios recientes han mostrado beneficios en combinación con quimioterapia para ciertos cánceres de mama triple negativos. Sin embargo, como todo tratamiento, tiene posibles efectos secundarios relacionados con la activación inmunitaria. ¿Quieres conocer más sobre cómo funciona este tipo de tratamiento?"
            ]),

            # Reconstrucción mamaria
            (r'.*\b(opciones|tipos) de reconstrucci[óo]n (mamaria|de mama|de pecho|de seno)\b.*', [
                "Las principales opciones de reconstrucción mamaria incluyen: 1) Implantes (silicona o solución salina), 2) Reconstrucción con tejido propio (colgajos de diferentes partes del cuerpo como abdomen, espalda o glúteos), y 3) Una combinación de ambas técnicas. Cada opción tiene ventajas y consideraciones específicas. ¿Te gustaría información detallada sobre alguna de estas opciones?",
                "La reconstrucción puede realizarse inmediatamente después de la mastectomía o posteriormente (diferida). La timing depende de factores como necesidad de radioterapia, preferencias personales y recomendaciones médicas. La reconstrucción inmediata ofrece beneficios psicológicos, mientras que la diferida permite más tiempo para considerar opciones. ¿Tienes preferencia por alguno de estos enfoques?",
                "Las técnicas modernas de reconstrucción mamaria han avanzado significativamente, permitiendo resultados naturales y satisfactorios. Sin embargo, es importante tener expectativas realistas: una mama reconstruida no tendrá la misma sensación que la original y pueden necesitarse múltiples cirugías para lograr el resultado deseado. ¿Tienes preguntas específicas sobre el proceso de recuperación?"
            ]),

            # Cáncer de mama en hombres
            (r'.*\b(cancer|cáncer) de (mama|pecho|seno) (en|de) (hombres|varones)\b.*', [
                "El cáncer de mama en hombres representa aproximadamente el 1% de todos los casos de cáncer de mama. Aunque es raro, los hombres tienen tejido mamario que puede desarrollar cáncer. Los síntomas suelen incluir un bulto firme e indoloro, cambios en el pezón o secreción. ¿Hay algún aspecto específico que te interese sobre este tema?",
                "Los factores de riesgo para cáncer de mama masculino incluyen edad avanzada, antecedentes familiares, mutaciones genéticas (especialmente BRCA2), síndrome de Klinefelter, exposición a estrógenos, y enfermedades hepáticas. El diagnóstico y tratamiento son similares a los utilizados en mujeres, con algunas consideraciones específicas. ¿Conoces a alguien afectado por esta condición?",
                "El cáncer de mama en hombres suele diagnosticarse en etapas más avanzadas, en parte debido a la menor conciencia sobre esta posibilidad. Es importante que los hombres conozcan los cambios que deben vigilar y consulten al médico si notan algo inusual en la zona del pecho. ¿Te gustaría información sobre recursos específicos para hombres con cáncer de mama?"
            ]),

            # Medicina de precisión
            (r'.*\b(medicina personalizada|medicina de precisi[óo]n|tratamiento personalizado)\b.*', [
                "La medicina de precisión en cáncer de mama consiste en adaptar el tratamiento a las características moleculares específicas del tumor de cada paciente. Mediante análisis genómicos y otros biomarcadores, los médicos pueden seleccionar terapias que tienen más probabilidad de ser efectivas y menos tóxicas para cada caso individual. ¿Te gustaría saber más sobre los test genómicos disponibles?",
                "Test como Oncotype DX, MammaPrint o PAM50 analizan la expresión de múltiples genes en el tumor para predecir el riesgo de recurrencia y el potencial beneficio de la quimioterapia. Estos test ayudan a tomar decisiones más informadas sobre el tratamiento, evitando terapias innecesarias en algunos casos. ¿Has discutido estos test con tu oncólogo?",
                "La medicina de precisión está transformando el tratamiento del cáncer de mama, permitiendo enfoques más individualizados. Además de los test genómicos, la secuenciación del ADN tumoral puede identificar mutaciones específicas para las que existen terapias dirigidas. Este campo evoluciona rápidamente con nuevas opciones terapéuticas emergiendo continuamente. ¿Hay algún aspecto de la medicina personalizada que te interese particularmente?"
            ]),

            # Efectos a largo plazo
            (r'.*\b(efectos|secuelas|consecuencias) a largo plazo\b.*', [
                "Los efectos a largo plazo después del tratamiento de cáncer de mama pueden incluir linfedema (hinchazón del brazo), fatiga crónica, cambios cognitivos ('quimio-cerebro'), menopausia prematura, problemas de fertilidad, cambios en la imagen corporal, y riesgo de segundos cánceres o problemas cardiovasculares. La intensidad varía según la persona y los tratamientos recibidos. ¿Hay algún efecto específico que te preocupe?",
                "El linfedema, causado por la extirpación o daño de ganglios linfáticos, afecta aproximadamente al 20% de las supervivientes. Puede desarrollarse incluso años después del tratamiento. Estrategias preventivas y de manejo incluyen ejercicios específicos, cuidado meticuloso de la piel y, en algunos casos, terapia descongestiva. ¿Te gustaría información sobre prevención del linfedema?",
                "Algunos efectos a largo plazo, como los sofocos o dolores articulares por terapia hormonal, pueden ser manejados con medicación o cambios en el estilo de vida. Otros, como el impacto emocional o los cambios en la sexualidad, pueden beneficiarse de asesoramiento profesional. Es importante discutir cualquier síntoma persistente con tu equipo médico. ¿Estás experimentando algún efecto secundario particular que te preocupe?"
            ]),

            # Predisposición genética
            (r'.*\b(prueba|test|estudio) (genético|gen[ée]tica)\b.*', [
                "Las pruebas genéticas para cáncer de mama analizan mutaciones en genes como BRCA1, BRCA2, PALB2, CHEK2, ATM, entre otros, que pueden aumentar significativamente el riesgo. Estas pruebas suelen recomendarse para personas con fuerte historia familiar, diagnóstico a edad temprana, o ciertos tipos de cáncer. ¿Te han recomendado realizarte pruebas genéticas?",
                "Un resultado positivo en pruebas genéticas no significa que desarrollarás cáncer, sino que tienes mayor riesgo. Esto permite implementar estrategias como vigilancia intensificada, medicamentos preventivos o cirugías profilácticas. También tiene implicaciones para familiares que podrían compartir estas mutaciones. ¿Hay antecedentes de cáncer de mama u ovario en tu familia?",
                "El asesoramiento genético antes y después de las pruebas es fundamental para entender las implicaciones de los resultados. Un consejero genético puede explicar qué pruebas son apropiadas, interpretar los resultados y discutir opciones de manejo de riesgo adaptadas a tu situación. ¿Has considerado consultar con un especialista en genética?"
            ]),

            # Cáncer inflamatorio
            (r'.*\b(c[áa]ncer|carcinoma) inflamatorio\b.*', [
                "El cáncer de mama inflamatorio es un tipo raro pero agresivo que representa del 1-5% de los casos. Se caracteriza por enrojecimiento, hinchazón y sensación de calor en la mama, piel de naranja, y a veces inversión del pezón. A diferencia de otros tipos, suele manifestarse como estos cambios inflamatorios más que como un bulto definido. ¿Has notado alguno de estos síntomas?",
                "El diagnóstico del cáncer inflamatorio es a menudo un desafío pues sus síntomas pueden confundirse con mastitis (infección mamaria). Se requiere una biopsia para confirmar, y pruebas de imagen para evaluar la extensión. Este tipo de cáncer suele diagnosticarse en etapas más avanzadas debido a su rápida progresión. ¿Tienes preguntas específicas sobre su diagnóstico?",
                "El tratamiento del cáncer inflamatorio es multidisciplinario, generalmente comenzando con quimioterapia neoadyuvante, seguida de cirugía (habitualmente mastectomía) y radioterapia. Aunque históricamente ha tenido peor pronóstico que otros tipos, los avances en tratamientos han mejorado significativamente las tasas de supervivencia. ¿Deseas información más detallada sobre opciones terapéuticas?"
            ]),

            # Cáncer de mama durante el embarazo
            (r'.*\b(c[áa]ncer|carcinoma) (de|durante) (el)? embarazo\b.*', [
                "El cáncer de mama durante el embarazo es poco común, afectando aproximadamente a 1 de cada 3,000 embarazos. Su diagnóstico puede ser complicado porque los cambios normales en las mamas durante el embarazo pueden ocultar síntomas. Sin embargo, cualquier masa persistente o cambio preocupante debe ser evaluado. ¿Estás embarazada y te han encontrado alguna anomalía?",
                "El tratamiento depende de la etapa del cáncer y el trimestre del embarazo. La cirugía es generalmente segura durante todo el embarazo. La quimioterapia puede administrarse en el segundo y tercer trimestre (evitando el primero debido al desarrollo fetal), mientras que la radioterapia y terapia hormonal suelen posponerse hasta después del parto. ¿Te gustaría información más específica sobre alguna opción de tratamiento?",
                "Es importante saber que tratar el cáncer durante el embarazo es posible en la mayoría de los casos, protegiendo tanto a la madre como al bebé. Un equipo multidisciplinario que incluya oncólogos y especialistas en medicina materno-fetal puede desarrollar un plan de tratamiento personalizado. La terminación del embarazo rara vez es necesaria. ¿Hay aspectos específicos de esta situación que te preocupen?"
            ]),

            # Consejo genético
            (r'.*\b(consejo|asesoramiento) gen[ée]tico\b.*', [
                "El consejo genético es un servicio que proporciona información y apoyo a personas con riesgo de padecer enfermedades hereditarias como ciertos tipos de cáncer de mama. Un consejero genético evalúa tu historia familiar, explica las pruebas disponibles, interpreta los resultados y discute opciones de manejo de riesgo. ¿Te interesa saber si deberías considerar este servicio?",
                "Durante una sesión de consejo genético para cáncer de mama, se crea un árbol genealógico detallado analizando al menos tres generaciones. Esto ayuda a identificar patrones que sugieran predisposición hereditaria y determinar qué miembros de la familia podrían beneficiarse de pruebas genéticas. ¿Conoces bien el historial de cáncer en tu familia?",
                "El consejo genético no solo proporciona información médica sino también apoyo psicológico para manejar las implicaciones emocionales de conocer tu predisposición genética. Es un proceso que te empodera para tomar decisiones informadas sobre vigilancia, prevención y planificación familiar. ¿Has considerado buscar este tipo de asesoramiento?"
            ]),

            # Cáncer de mama en adultos jóvenes
            (r'.*\b(c[áa]ncer|carcinoma) (en|de) (j[óo]venes|adultos j[óo]venes)\b.*', [
                "El cáncer de mama en adultos jóvenes (menores de 40 años) representa aproximadamente el 7% de todos los casos. Suele ser más agresivo, con mayor proporción de subtipos como triple negativo o HER2-positivo. El diagnóstico a menudo se retrasa porque tanto pacientes como médicos no sospechan cáncer en personas jóvenes. ¿Tienes menos de 40 años y te preocupa el cáncer de mama?",
                "Los jóvenes con cáncer de mama enfrentan desafíos únicos como preocupaciones sobre fertilidad, menopausia prematura inducida por tratamientos, impacto en relaciones, carrera profesional, y más años viviendo con posibles efectos secundarios a largo plazo. Existen recursos específicos para ayudar con estos aspectos. ¿Hay alguna de estas preocupaciones que te afecte particularmente?",
                "Para adultos jóvenes con antecedentes familiares significativos o con resultado positivo en pruebas genéticas, existen protocolos de vigilancia que pueden comenzar a los 25-30 años o incluso antes. Estos pueden incluir mamografías, resonancias magnéticas y exámenes clínicos regulares. ¿Te has planteado comenzar con revisiones tempranas?"
            ]),

            # Trasplante de médula ósea
            (r'.*\b(trasplante|transplante) (de)? (m[ée]dula|c[ée]lulas madre)\b.*', [
                "El trasplante de células madre (o trasplante de médula ósea de alta dosis) no es un tratamiento estándar para la mayoría de los cánceres de mama. Sin embargo, puede considerarse en ciertos casos de cáncer metastásico o de alto riesgo como parte de ensayos clínicos. Consiste en administrar altas dosis de quimioterapia seguidas de un rescate con células madre para restaurar la función medular. ¿Buscas información sobre ensayos clínicos de esta terapia?",
                "Este procedimiento conlleva riesgos significativos, incluyendo complicaciones potencialmente mortales, y su beneficio en el cáncer de mama sigue siendo objeto de investigación. Los estudios iniciales mostraron resultados mixtos, con beneficios limitados en la supervivencia general para la mayoría de las pacientes. ¿Te han mencionado esta opción como parte de tu tratamiento?",
                "Hoy en día, las investigaciones se centran más en inmunoterapias, terapias dirigidas y combinaciones de tratamientos existentes que en trasplantes de médula ósea para cáncer de mama. Si estás interesada en tratamientos innovadores, existen numerosos ensayos clínicos explorando opciones menos tóxicas y potencialmente más efectivas. ¿Quieres información sobre cómo acceder a ensayos clínicos?"
            ]),

            # Enfermedad de Paget del pezón
            (r'.*\b(enfermedad|mal) de Paget\b.*', [
                "La enfermedad de Paget del pezón es un tipo raro de cáncer de mama que afecta la piel del pezón y la areola. Representa aproximadamente el 1-4% de todos los casos de cáncer de mama. Los síntomas incluyen descamación, enrojecimiento, picazón, ardor, y a veces secreción o sangrado del pezón. Estos síntomas suelen confundirse inicialmente con afecciones dermatológicas benignas. ¿Has notado alguno de estos cambios?",
                "Esta enfermedad generalmente está asociada con un carcinoma ductal subyacente, que puede ser invasivo o in situ. El diagnóstico se confirma mediante biopsia de la piel afectada. Las pruebas de imagen como mamografía, ecografía o resonancia magnética son importantes para evaluar la extensión de la enfermedad. ¿Te han recomendado alguna de estas pruebas?",
                "El tratamiento depende de si hay un tumor subyacente y su extensión. Puede incluir desde una escisión local del pezón y areola con radioterapia, hasta mastectomía en casos más extensos. El pronóstico es generalmente bueno cuando se diagnostica tempranamente y se trata adecuadamente. ¿Tienes preguntas específicas sobre las opciones de tratamiento?"
            ]),

            # Medicina complementaria y alternativa
            (r'.*\b(terapias|tratamientos|medicina) (complementari[ao]s?|alternativ[ao]s?)\b.*', [
                "Las terapias complementarias son aquellas que se utilizan junto con el tratamiento médico convencional, mientras que las alternativas son las que se usan en lugar de este. Algunas terapias complementarias con evidencia de beneficios incluyen yoga, meditación, acupuntura y ejercicio físico, que pueden ayudar a manejar síntomas y mejorar la calidad de vida. ¿Hay alguna terapia específica que te interese?",
                "Es crucial discutir cualquier terapia complementaria con tu equipo médico, ya que algunas pueden interferir con tratamientos convencionales. Por ejemplo, ciertos suplementos herbales pueden interactuar con medicamentos como la quimioterapia o la terapia hormonal. Tu oncólogo puede ayudarte a identificar opciones seguras y potencialmente beneficiosas. ¿Has considerado alguna terapia complementaria?",
                "Mantén una perspectiva crítica ante terapias que prometen 'curar' el cáncer sin evidencia científica sólida. Las terapias complementarias pueden ser valiosas para manejar síntomas y mejorar el bienestar, pero no deben reemplazar tratamientos médicos basados en evidencia. Organizaciones como la Sociedad Americana del Cáncer ofrecen información confiable sobre estas terapias. ¿Te gustaría conocer recursos para evaluar la evidencia detrás de diferentes enfoques?"
            ]),

            # Cáncer de mama y ejercicio
            (r'.*\b(ejercicio|actividad f[íi]sica|deporte) (y|para|durante|despu[ée]s) (c[áa]ncer|tratamiento)\b.*', [
                "El ejercicio regular es beneficioso tanto durante como después del tratamiento del cáncer de mama. Estudios muestran que puede reducir la fatiga, mejorar la capacidad funcional, elevar el estado de ánimo, y potencialmente reducir el riesgo de recurrencia. Se recomienda aproximadamente 150 minutos semanales de actividad moderada, ajustada según tu condición física. ¿Te interesa desarrollar una rutina de ejercicios adaptada?",
                "Durante el tratamiento, el ejercicio debe adaptarse a tu nivel de energía y posibles limitaciones. Actividades de bajo impacto como caminar, nadar o yoga pueden ser ideales. Después del tratamiento, puedes aumentar gradualmente la intensidad según te sientas cómoda. Es importante consultar con tu equipo médico antes de comenzar cualquier programa. ¿Has hablado con tu médico sobre el ejercicio?",
                "El ejercicio específico para fortalecer el brazo y hombro después de la cirugía de mama es particularmente importante para recuperar la movilidad y prevenir el linfedema. Un fisioterapeuta especializado puede proporcionar ejercicios seguros y efectivos adaptados a tu situación. Además, programas como 'Ejercicio es Medicina' ofrecen recursos específicos para supervivientes de cáncer. ¿Te gustaría información sobre programas de ejercicio supervisado?"
            ]),

            # Efectos secundarios específicos
            (r'.*\b(neuropat[íi]a|hormigueo|entumecimiento|dolor) (en)? (manos|pies|extremidades)\b.*', [
                "La neuropatía periférica es un efecto secundario común de ciertos quimioterápicos como taxanos (paclitaxel, docetaxel) y compuestos de platino. Se manifiesta como hormigueo, entumecimiento o dolor en manos y pies. Puede ser temporal o, en algunos casos, persistir después del tratamiento. ¿Estás experimentando estos síntomas actualmente?",
                "Existen varias estrategias para manejar la neuropatía, incluyendo medicamentos para el dolor neuropático (como gabapentina o duloxetina), terapias físicas, acupuntura, y técnicas de estimulación eléctrica. Es importante comunicar estos síntomas a tu oncólogo, quien puede ajustar el tratamiento si es necesario. ¿Has discutido estos síntomas con tu médico?",
                "Medidas preventivas como la crioterapia (guantes y calcetines fríos durante la infusión de quimioterapia) pueden reducir el riesgo en algunos casos. Para la neuropatía ya establecida, es importante tomar precauciones de seguridad en el hogar, como usar zapatos con buen soporte y comprobar la temperatura del agua, ya que la sensibilidad puede estar alterada. ¿Te gustaría más consejos prácticos para manejar estos síntomas?"
            ]),

            # Nuevos tratamientos/investigación
            (r'.*\b(nuevos|recientes|[úu]ltimos) (tratamientos|avances|investigaciones)\b.*', [
                "Los avances recientes en cáncer de mama incluyen terapias dirigidas más específicas, como inhibidores CDK4/6 para cáncer con receptores hormonales positivos, nuevos anticuerpos conjugados (ADC) como trastuzumab deruxtecan, y avances en inmunoterapia para subtipos específicos. Estos tratamientos están expandiendo las opciones, especialmente para enfermedad metastásica. ¿Hay algún tipo específico de tratamiento que te interese conocer?",
                "La biopsia líquida, que detecta ADN tumoral circulante en sangre, está emergiendo como herramienta para monitorizar la respuesta al tratamiento y detectar recurrencias tempranamente. También avanza la investigación en vacunas terapéuticas y tratamientos basados en la secuenciación genómica completa del tumor. ¿Te interesa conocer más sobre alguna de estas tecnologías?",
                "La investigación actual se centra en encontrar biomarcadores que predigan mejor la respuesta a tratamientos específicos, estrategias para superar resistencias a terapias existentes, y enfoques para desescalar tratamientos en pacientes de bajo riesgo, reduciendo toxicidades innecesarias. Los ensayos clínicos son fundamentales para acceder a estos avances. ¿Te gustaría información sobre cómo participar en ensayos clínicos?"
            ]),

            # Aspectos psicológicos
            (r'.*\b(imagen corporal|sexualidad|intimidad|relaciones)\b.*', [
                "Los cambios en la imagen corporal después del tratamiento de cáncer de mama pueden tener un impacto significativo. Es normal experimentar sentimientos complejos sobre estos cambios. Existen recursos como terapia especializada, grupos de apoyo y programas como 'Look Good Feel Better' que pueden ayudar a adaptarse a la nueva imagen. ¿Te gustaría conocer recursos específicos?",
                "Los cambios en la sexualidad e intimidad son frecuentes pero poco discutidos. Pueden incluir disminución del deseo, sequedad vaginal, molestias durante las relaciones, o preocupaciones sobre cicatrices y cambios corporales. Existen soluciones como lubricantes, dilatadores vaginales, y terapia sexual que pueden ser de gran ayuda. ¿Has podido hablar de estos aspectos con tu equipo médico?",
                "Para las relaciones de pareja, la comunicación abierta es crucial. Puede ser beneficioso incluir a tu pareja en algunas consultas médicas y buscar apoyo conjunto a través de consejería. Muchas parejas reportan que, aunque desafiante, esta experiencia puede fortalecer su vínculo cuando se afronta juntos. ¿Cómo ha impactado tu diagnóstico en tus relaciones personales?"
            ]),

            # Manejo del cáncer como enfermedad crónica
            (r'.*\b(c[áa]ncer cr[óo]nico|vivir con c[áa]ncer|convivir con c[áa]ncer)\b.*', [
                "Para muchas personas con cáncer de mama metastásico o recurrente, la enfermedad se maneja como una condición crónica, con períodos de tratamiento activo y otros de mantenimiento o vigilancia. Este enfoque se centra tanto en prolongar la vida como en mantener su calidad. ¿Estás actualmente en alguna fase de tratamiento para enfermedad metastásica?",
                "Vivir con cáncer como enfermedad crónica implica desafíos únicos, incluyendo la incertidumbre sobre el futuro, manejar tratamientos continuos y sus efectos, y el impacto emocional de vivir con la enfermedad a largo plazo. Estrategias como establecer rutinas, mantener actividades significativas y buscar apoyo psicológico pueden ser muy beneficiosas. ¿Qué aspectos de vivir con cáncer crónico te resultan más desafiantes?",
                "Un aspecto importante del manejo del cáncer crónico es el concepto de 'supervivencia' incluso con enfermedad activa. Esto implica enfocarse en vivir plenamente en el presente mientras se maneja la enfermedad. Recursos como programas de rehabilitación oncológica, apoyo psicosocial y comunidades específicas para cáncer metastásico pueden ser de gran valor. ¿Conoces alguno de estos recursos en tu área?"
            ]),

            # Aspectos laborales y financieros
            (r'.*\b(trabajo|laboral|empleo|despido|baja|incapacidad|financiero|econ[óo]mico)\b.*', [
                "Manejar aspectos laborales durante el tratamiento del cáncer puede ser complicado. Es importante conocer tus derechos laborales, que pueden incluir adaptaciones razonables del puesto, flexibilidad horaria, o licencias médicas. Un trabajador social oncológico puede ayudarte a navegar estas cuestiones. ¿Has hablado con recursos humanos en tu trabajo sobre tu situación?",
                "El impacto financiero del cáncer puede ser significativo. Además de gastos médicos directos, pueden surgir costos indirectos como transporte, cuidado infantil o pérdida de ingresos. Existen recursos como programas de asistencia financiera, fundaciones y organizaciones sin fines de lucro que ofrecen apoyo. ¿Te gustaría información sobre recursos financieros en tu área?",
                "Planificar con anticipación puede ayudar a manejar el impacto económico. Esto incluye revisar tu cobertura de seguro, explorar beneficios por discapacidad o incapacidad, organizar un presupuesto ajustado y, si es necesario, negociar planes de pago con proveedores médicos. ¿Has comenzado a planificar estos aspectos financieros?"
            ])
        ]
        
        # Respuestas genéricas cuando no hay coincidencia
        self.fallback_responses = [
            "El cáncer de mama puede ser abrumador. ¿Hay algún aspecto específico sobre el que necesites información o apoyo?",
            "Entiendo tu interés en el cáncer de mama. ¿Puedes detallar más tu pregunta para brindarte información más precisa?",
            "El viaje del cáncer de mama es diferente para cada persona. ¿Hay algún aspecto particular que te gustaría explorar?",
            "A veces es difícil expresar todas nuestras preocupaciones sobre el cáncer de mama. ¿Hay algo específico que te esté preocupando?",
            "Estoy aquí para brindarte información sobre el cáncer de mama. ¿Puedes reformular tu pregunta para entender mejor lo que necesitas?",
            "El conocimiento sobre el cáncer de mama puede ser empoderador. ¿Hay algún área específica sobre la que te gustaría aprender más?"
        ]
        
        # Variables para memoria de la conversación
        self.history = []
    
    def preprocess_input(self, user_input):
        """Preprocesa la entrada del usuario"""
        # Convertir a minúsculas
        processed = user_input.lower()
        # Otros procesamientos si son necesarios
        return processed
    
    def postprocess_response(self, response, matches):
        """Personaliza la respuesta con información extraída del input del usuario"""
        # Si hay grupos de captura (matches) los utilizamos para formatear la respuesta
        if matches:
            try:
                # Intentamos formatear la respuesta con los grupos capturados
                return response.format(*matches)
            except (IndexError, KeyError):
                # Si hay algún error, devolvemos la respuesta sin formatear
                return response
        return response
    
    def respond_to(self, user_input):
        """Genera una respuesta basada en el input del usuario"""
        processed_input = self.preprocess_input(user_input)
        
        # Guardar en historial
        self.history.append(processed_input)
        
        # Buscar coincidencias con patrones
        for pattern, responses in self.patterns:
            match = re.match(pattern, processed_input)
            if match:
                # Extraer grupos capturados
                matches = [group for group in match.groups()]
                
                # Seleccionar respuesta aleatoria para este patrón
                selected_response = random.choice(responses)
                
                # Personalizar la respuesta con los grupos capturados
                final_response = self.postprocess_response(selected_response, matches)
                
                return final_response
        
        # Si no hay coincidencias, usar respuesta genérica
        return random.choice(self.fallback_responses)
    
    def start_conversation(self):
        """Inicia una conversación interactiva"""
        print("MammaELIZA: Hola, soy un asistente virtual sobre cáncer de mama.")
        print(f"MammaELIZA: {self.disclaimer}")
        print("MammaELIZA: ¿En qué puedo ayudarte hoy? (Escribe 'adiós' para terminar)")
        
        while True:
            user_input = input("\nTú: ")
            
            if user_input.lower() in ['adiós', 'adios', 'salir', 'exit', 'quit']:
                print("MammaELIZA: Cuídate mucho. Recuerda la importancia de las revisiones regulares. ¡Hasta pronto!")
                break
            
            response = self.respond_to(user_input)
            print(f"MammaELIZA: {response}")

# %%
# Crear y ejecutar el chatbot
if __name__ == "__main__":
    eliza = MammaELIZA()
    eliza.start_conversation()
# Out:
# MammaELIZA: Hola, soy un asistente virtual sobre cáncer de mama.
# MammaELIZA: Nota: Soy un programa informático de apoyo. No soy médico ni puedo proporcionar diagnósticos o consejos médicos personalizados. Por favor, consulta siempre con profesionales de la salud para decisiones médicas.
# MammaELIZA: ¿En qué puedo ayudarte hoy? (Escribe 'adiós' para terminar)
# MammaELIZA: El conocimiento sobre el cáncer de mama puede ser empoderador. ¿Hay algún área específica sobre la que te gustaría aprender más?
# MammaELIZA: El viaje del cáncer de mama es diferente para cada persona. ¿Hay algún aspecto particular que te gustaría explorar?
# MammaELIZA: El cáncer de mama es una enfermedad en la que las células mamarias crecen de forma descontrolada, formando tumores que pueden invadir el tejido circundante. Comienza generalmente en los conductos que transportan leche al pezón o en las glándulas productoras de leche. ¿Te gustaría saber sobre algún aspecto específico?
# ...
